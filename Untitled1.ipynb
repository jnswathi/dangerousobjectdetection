# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.5/749.5 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 33.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 51.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 61.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 762.4 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
from ultralytics import YOLO
import openvino as ov
model = YOLO('/content/gdrive/MyDrive/Colab Notebooks/best.pt')

model.export(format = 'openvino')
# Out:
# Ultralytics YOLOv8.1.44 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3006818 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/gdrive/MyDrive/Colab Notebooks/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 10, 8400) (5.9 MB)
#
# OpenVINO: starting export with openvino 2024.0.0-14509-34caeefd078-releases/2024/0...
# OpenVINO: export success ✅ 9.3s, saved as '/content/gdrive/MyDrive/Colab Notebooks/best_openvino_model/' (11.8 MB)
#
# Export complete (13.3s)
# Results saved to /content/gdrive/MyDrive/Colab Notebooks
# Predict:         yolo predict task=detect model=/content/gdrive/MyDrive/Colab Notebooks/best_openvino_model imgsz=640
# Validate:        yolo val task=detect model=/content/gdrive/MyDrive/Colab Notebooks/best_openvino_model imgsz=640 data=/content/gdrive/MyDrive/Colab Notebooks/capstone/final 2/data.yaml
# Visualize:       https://netron.app
# ...

# %%
# !pip install openvino
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 19.6 MB/s eta 0:00:00
# ...

# %%
ov_model = YOLO('/content/gdrive/MyDrive/Colab Notebooks/best_openvino_model')
results = ov_model('/content/gdrive/MyDrive/Colab Notebooks/base.jpeg')
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading /content/gdrive/MyDrive/Colab Notebooks/best_openvino_model for OpenVINO inference...
# Using OpenVINO LATENCY mode for batch=1 inference...
#
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/base.jpeg: 640x640 2 knifes, 291.1ms
# Speed: 16.1ms preprocess, 291.1ms inference, 2993.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
results1 = model('/content/gdrive/MyDrive/Colab Notebooks/base.jpeg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/base.jpeg: 480x640 2 knifes, 518.1ms
# Speed: 4.3ms preprocess, 518.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)

# %%
results=ov_model('/content/gdrive/MyDrive/Colab Notebooks/base.jpeg',
                  save=True, project='/content/gdrive/MyDrive/Colab Notebooks', name='test', exist_ok=True)
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/base.jpeg: 640x640 2 knifes, 310.2ms
# Speed: 17.3ms preprocess, 310.2ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/gdrive/MyDrive/Colab Notebooks/test
